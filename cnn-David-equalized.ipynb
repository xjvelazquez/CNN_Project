# %%
from david_cnn import *

# %%
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# %%
# Check if your system supports CUDA
use_cuda = torch.cuda.is_available()

# Setup GPU optimization if CUDA is supported
if use_cuda:
    computing_device = torch.device("cuda")
    extras = {"num_workers": 1, "pin_memory": True}
    print("CUDA is supported")
else: # Otherwise, train on the CPU
    computing_device = torch.device("cpu")
    extras = False
    print("CUDA NOT supported")

net=Nnet().to(computing_device)
net.apply(weights_init)

# Print the model
print(net)

#loss criteria are defined in the torch.nn package
criterion = nn.CrossEntropyLoss()


#Instantiate the gradient descent optimizer - use Adam optimizer with default parameters
optimizer = optim.Adam(net.parameters(),lr = 0.001)
# Out:
# CUDA is supported
# Nnet(
#   (main): Sequential(
#     (0): Conv2d(3, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): ReLU(inplace=True)
#     (2): Conv2d(18, 30, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(30, 35, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (6): Conv2d(35, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(40, 45, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (11): Conv2d(45, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (12): BatchNorm2d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): ReLU(inplace=True)
#     (14): MaxPool2d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#     (15): Conv2d(50, 55, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (16): Conv2d(55, 60, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (17): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (18): ReLU(inplace=True)
#     (19): MaxPool2d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc): Sequential(
#     (0): Linear(in_features=240, out_features=500, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=500, out_features=500, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=500, out_features=500, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=500, out_features=201, bias=True)
#   )
# )

# %%
transform = transforms.Compose([transforms.Resize(224), transforms.CenterCrop(224), transforms.ToTensor()])
dataset = loader('train_balanced.csv','./equalized/',transform=transform)
batch_size = 64
validation_split = .2
shuffle_dataset = True
random_seed= 42

# Creating data indices for training and validation splits:
dataset_size = len(dataset)
indices = list(range(dataset_size))
split = int(np.floor(validation_split * dataset_size))
if shuffle_dataset :
    np.random.seed(random_seed)
    np.random.shuffle(indices)
train_indices, val_indices = indices[split:], indices[:split]

# Creating PT data samplers and loaders:
train_sampler = SubsetRandomSampler(train_indices)
valid_sampler = SubsetRandomSampler(val_indices)

train_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, 
                                           sampler=train_sampler)
validation_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                                sampler=valid_sampler)

# %%
# Track the loss across training
total_loss = []
avg_minibatch_loss = []
N = 50

for epoch in range(50):
    N_minibatch_loss = 0.0
    correct = 0
    total = 0

    # Get the next minibatch of images, labels for training
    for minibatch_count, (images, labels) in enumerate(train_loader, 0):
        #print("mini_batch", minibatch_count)
        # Zero out the stored gradient (buffer) from the previous iteration
        optimizer.zero_grad()
        # Put the minibatch data in CUDA Tensors and run on the GPU if supported
        images, labels = images.to(computing_device), labels.to(computing_device)
        # Perform the forward pass through the network and compute the loss
        outputs = net(images)
        
        loss = criterion(outputs, labels)
        # Automagically compute the gradients and backpropagate the loss through the network
        loss.backward()

        # Update the weights
        optimizer.step()    
        # Add this iteration's loss to the total_loss
        total_loss.append(loss.item())
        N_minibatch_loss += loss
               
        
        if minibatch_count % N == 49:
            #Print the loss averaged over the last N mini-batches
            N_minibatch_loss /= N
            print('Epoch %d, average minibatch %d loss: %.3f' % (epoch + 1, minibatch_count+1, N_minibatch_loss))
            # Add the averaged loss over N minibatches and reset the counter
            avg_minibatch_loss.append(N_minibatch_loss)
            N_minibatch_loss = 0.0

    print("Finished", epoch + 1, "epochs of training")
    # TODO: Implement validation #with torch.no_grad():
    
    with torch.no_grad():
        for minibatch_count, (images, labels) in enumerate(validation_loader, 0):
            # Put the minibatch data in CUDA Tensors and run on the GPU if supported
            images, labels = images.to(computing_device), labels.to(computing_device)
            for index in range(N):    
                real_y = labels[index]
                #print('real_y', real_y)
                out = net(images[index].view(-1,3,224,224))
                #print('out:', out)
                pred_y = torch.argmax(out)
                #print('pred_y', pred_y)

                if (real_y.item() == pred_y.item()):
                    correct += 1
                total += 1
    print('Accuracy: %.3f' % ((correct/total)*100))
# Out:
# Epoch 1, average minibatch 50 loss: 5.265
# Epoch 1, average minibatch 100 loss: 5.168
# Epoch 1, average minibatch 150 loss: 5.007
# Epoch 1, average minibatch 200 loss: 4.899
# Epoch 1, average minibatch 250 loss: 4.704
# Epoch 1, average minibatch 300 loss: 4.608
# Epoch 1, average minibatch 350 loss: 4.512
# Finished 1 epochs of training
# Accuracy: 4.383
# Epoch 2, average minibatch 50 loss: 4.339
# Epoch 2, average minibatch 100 loss: 4.218
# Epoch 2, average minibatch 150 loss: 4.180
# Epoch 2, average minibatch 200 loss: 4.131
# Epoch 2, average minibatch 250 loss: 4.070
# Epoch 2, average minibatch 300 loss: 3.988
# Epoch 2, average minibatch 350 loss: 3.907
# Finished 2 epochs of training
# Accuracy: 8.234
# Epoch 3, average minibatch 50 loss: 3.747
# Epoch 3, average minibatch 100 loss: 3.750
# Epoch 3, average minibatch 150 loss: 3.624
# Epoch 3, average minibatch 200 loss: 3.499
# Epoch 3, average minibatch 250 loss: 3.434
# Epoch 3, average minibatch 300 loss: 3.431
# Epoch 3, average minibatch 350 loss: 3.299
# Finished 3 epochs of training
# Accuracy: 16.766
# Epoch 4, average minibatch 50 loss: 3.178
# Epoch 4, average minibatch 100 loss: 3.099
# Epoch 4, average minibatch 150 loss: 3.078
# Epoch 4, average minibatch 200 loss: 2.976
# Epoch 4, average minibatch 250 loss: 2.947
# Epoch 4, average minibatch 300 loss: 2.905
# Epoch 4, average minibatch 350 loss: 2.895
# Finished 4 epochs of training
# Accuracy: 22.043
# Epoch 5, average minibatch 50 loss: 2.662
# Epoch 5, average minibatch 100 loss: 2.637
# Epoch 5, average minibatch 150 loss: 2.583
# Epoch 5, average minibatch 200 loss: 2.554
# Epoch 5, average minibatch 250 loss: 2.555
# Epoch 5, average minibatch 300 loss: 2.522
# Epoch 5, average minibatch 350 loss: 2.448
# Finished 5 epochs of training
# Accuracy: 28.915
# Epoch 6, average minibatch 50 loss: 2.312
# Epoch 6, average minibatch 100 loss: 2.256
# Epoch 6, average minibatch 150 loss: 2.290
# Epoch 6, average minibatch 200 loss: 2.204
# Epoch 6, average minibatch 250 loss: 2.160
# Epoch 6, average minibatch 300 loss: 2.178
# Epoch 6, average minibatch 350 loss: 2.213
# Finished 6 epochs of training
# Accuracy: 34.787
# Epoch 7, average minibatch 50 loss: 1.974
# Epoch 7, average minibatch 100 loss: 1.962
# Epoch 7, average minibatch 150 loss: 1.970
# Epoch 7, average minibatch 200 loss: 1.975
# Epoch 7, average minibatch 250 loss: 1.908
# Epoch 7, average minibatch 300 loss: 1.856
# Epoch 7, average minibatch 350 loss: 1.956
# Finished 7 epochs of training
# Accuracy: 38.681
# Epoch 8, average minibatch 50 loss: 1.724
# Epoch 8, average minibatch 100 loss: 1.697
# Epoch 8, average minibatch 150 loss: 1.737
# Epoch 8, average minibatch 200 loss: 1.736
# Epoch 8, average minibatch 250 loss: 1.708
# Epoch 8, average minibatch 300 loss: 1.631
# Epoch 8, average minibatch 350 loss: 1.676
# Finished 8 epochs of training
# Accuracy: 41.489
# Epoch 9, average minibatch 50 loss: 1.446
# Epoch 9, average minibatch 100 loss: 1.447
# Epoch 9, average minibatch 150 loss: 1.483
# Epoch 9, average minibatch 200 loss: 1.508
# Epoch 9, average minibatch 250 loss: 1.470
# Epoch 9, average minibatch 300 loss: 1.523
# Epoch 9, average minibatch 350 loss: 1.595
# Finished 9 epochs of training
# Accuracy: 45.000
# Epoch 10, average minibatch 50 loss: 1.330
# Epoch 10, average minibatch 100 loss: 1.341
# Epoch 10, average minibatch 150 loss: 1.413
# Epoch 10, average minibatch 200 loss: 1.324
# Epoch 10, average minibatch 250 loss: 1.393
# Epoch 10, average minibatch 300 loss: 1.332
# Epoch 10, average minibatch 350 loss: 1.350
# Finished 10 epochs of training
# Accuracy: 46.447
# Epoch 11, average minibatch 50 loss: 1.170
# Epoch 11, average minibatch 100 loss: 1.245
# Epoch 11, average minibatch 150 loss: 1.207
# Epoch 11, average minibatch 200 loss: 1.250
# Epoch 11, average minibatch 250 loss: 1.185
# Epoch 11, average minibatch 300 loss: 1.171
# Epoch 11, average minibatch 350 loss: 1.186
# Finished 11 epochs of training
# Accuracy: 48.766
# Epoch 12, average minibatch 50 loss: 1.073
# Epoch 12, average minibatch 100 loss: 1.019
# Epoch 12, average minibatch 150 loss: 1.078
# Epoch 12, average minibatch 200 loss: 1.093
# Epoch 12, average minibatch 250 loss: 1.074
# Epoch 12, average minibatch 300 loss: 1.138
# Epoch 12, average minibatch 350 loss: 1.148
# Finished 12 epochs of training
# Accuracy: 46.979
# Epoch 13, average minibatch 50 loss: 0.910
# Epoch 13, average minibatch 100 loss: 0.932
# Epoch 13, average minibatch 150 loss: 1.016
# Epoch 13, average minibatch 200 loss: 1.056
# Epoch 13, average minibatch 250 loss: 1.015
# Epoch 13, average minibatch 300 loss: 1.055
# Epoch 13, average minibatch 350 loss: 1.081
# Finished 13 epochs of training
# Accuracy: 50.936
# Epoch 14, average minibatch 50 loss: 0.835
# Epoch 14, average minibatch 100 loss: 0.826
# Epoch 14, average minibatch 150 loss: 0.853
# Epoch 14, average minibatch 200 loss: 0.901
# Epoch 14, average minibatch 250 loss: 0.873
# Epoch 14, average minibatch 300 loss: 0.936
# Epoch 14, average minibatch 350 loss: 0.890
# Finished 14 epochs of training
# Accuracy: 51.340
# Epoch 15, average minibatch 50 loss: 0.731
# Epoch 15, average minibatch 100 loss: 0.738
# Epoch 15, average minibatch 150 loss: 0.791
# Epoch 15, average minibatch 200 loss: 0.779
# Epoch 15, average minibatch 250 loss: 0.823
# Epoch 15, average minibatch 300 loss: 0.880
# Epoch 15, average minibatch 350 loss: 0.848
# Finished 15 epochs of training
# Accuracy: 52.255
# Epoch 16, average minibatch 50 loss: 0.691
# Epoch 16, average minibatch 100 loss: 0.689
# Epoch 16, average minibatch 150 loss: 0.719
# Epoch 16, average minibatch 200 loss: 0.727
# Epoch 16, average minibatch 250 loss: 0.768
# Epoch 16, average minibatch 300 loss: 0.739
# Epoch 16, average minibatch 350 loss: 0.785
# Finished 16 epochs of training
# Accuracy: 52.745
# Epoch 17, average minibatch 50 loss: 0.575
# Epoch 17, average minibatch 100 loss: 0.594
# Epoch 17, average minibatch 150 loss: 0.588
# Epoch 17, average minibatch 200 loss: 0.658
# Epoch 17, average minibatch 250 loss: 0.712
# Epoch 17, average minibatch 300 loss: 0.748
# Epoch 17, average minibatch 350 loss: 0.734
# Finished 17 epochs of training
# Accuracy: 53.362
# Epoch 18, average minibatch 50 loss: 0.536
# Epoch 18, average minibatch 100 loss: 0.500
# Epoch 18, average minibatch 150 loss: 0.556
# Epoch 18, average minibatch 200 loss: 0.602
# Epoch 18, average minibatch 250 loss: 0.587
# Epoch 18, average minibatch 300 loss: 0.614
# Epoch 18, average minibatch 350 loss: 0.658
# Finished 18 epochs of training
# Accuracy: 56.149
# Epoch 19, average minibatch 50 loss: 0.513
# Epoch 19, average minibatch 100 loss: 0.468
# Epoch 19, average minibatch 150 loss: 0.555
# Epoch 19, average minibatch 200 loss: 0.532
# Epoch 19, average minibatch 250 loss: 0.565
# Epoch 19, average minibatch 300 loss: 0.551
# Epoch 19, average minibatch 350 loss: 0.563
# Finished 19 epochs of training
# Accuracy: 56.745
# Epoch 20, average minibatch 50 loss: 0.389
# Epoch 20, average minibatch 100 loss: 0.421
# Epoch 20, average minibatch 150 loss: 0.490
# Epoch 20, average minibatch 200 loss: 0.477
# Epoch 20, average minibatch 250 loss: 0.462
# Epoch 20, average minibatch 300 loss: 0.538
# Epoch 20, average minibatch 350 loss: 0.529
# Finished 20 epochs of training
# Accuracy: 54.617
# Epoch 21, average minibatch 50 loss: 0.401
# Epoch 21, average minibatch 100 loss: 0.474
# Epoch 21, average minibatch 150 loss: 0.381
# Epoch 21, average minibatch 200 loss: 0.480
# Epoch 21, average minibatch 250 loss: 0.510
# Epoch 21, average minibatch 300 loss: 0.472
# Epoch 21, average minibatch 350 loss: 0.534
# Finished 21 epochs of training
# Accuracy: 55.617
# Epoch 22, average minibatch 50 loss: 0.347
# Epoch 22, average minibatch 100 loss: 0.359
# Epoch 22, average minibatch 150 loss: 0.385
# Epoch 22, average minibatch 200 loss: 0.394
# Epoch 22, average minibatch 250 loss: 0.405
# Epoch 22, average minibatch 300 loss: 0.453
# Epoch 22, average minibatch 350 loss: 0.464
# Finished 22 epochs of training
# Accuracy: 54.894
# Epoch 23, average minibatch 50 loss: 0.306
# Epoch 23, average minibatch 100 loss: 0.307
# Epoch 23, average minibatch 150 loss: 0.410
# Epoch 23, average minibatch 200 loss: 0.380
# Epoch 23, average minibatch 250 loss: 0.428
# Epoch 23, average minibatch 300 loss: 0.414
# Epoch 23, average minibatch 350 loss: 0.374
# Finished 23 epochs of training
# Accuracy: 56.021
# Epoch 24, average minibatch 50 loss: 0.275
# Epoch 24, average minibatch 100 loss: 0.301
# Epoch 24, average minibatch 150 loss: 0.316
# Epoch 24, average minibatch 200 loss: 0.319
# Epoch 24, average minibatch 250 loss: 0.360
# Epoch 24, average minibatch 300 loss: 0.378
# Epoch 24, average minibatch 350 loss: 0.412
# Finished 24 epochs of training
# Accuracy: 54.511
# Epoch 25, average minibatch 50 loss: 0.331
# Epoch 25, average minibatch 100 loss: 0.335
# Epoch 25, average minibatch 150 loss: 0.279
# Epoch 25, average minibatch 200 loss: 0.339
# Epoch 25, average minibatch 250 loss: 0.340
# Epoch 25, average minibatch 300 loss: 0.333
# Epoch 25, average minibatch 350 loss: 0.413
# Finished 25 epochs of training
# Accuracy: 52.745
# Epoch 26, average minibatch 50 loss: 0.250
# Epoch 26, average minibatch 100 loss: 0.245
# Epoch 26, average minibatch 150 loss: 0.286
# Epoch 26, average minibatch 200 loss: 0.320
# Epoch 26, average minibatch 250 loss: 0.344
# Epoch 26, average minibatch 300 loss: 0.332
# Epoch 26, average minibatch 350 loss: 0.321
# Finished 26 epochs of training
# Accuracy: 55.319
# Epoch 27, average minibatch 50 loss: 0.219
# Epoch 27, average minibatch 100 loss: 0.212
# Epoch 27, average minibatch 150 loss: 0.219
# Epoch 27, average minibatch 200 loss: 0.298
# Epoch 27, average minibatch 250 loss: 0.291
# Epoch 27, average minibatch 300 loss: 0.327
# Epoch 27, average minibatch 350 loss: 0.339
# Finished 27 epochs of training
# Accuracy: 56.957
# Epoch 28, average minibatch 50 loss: 0.192
# Epoch 28, average minibatch 100 loss: 0.191
# Epoch 28, average minibatch 150 loss: 0.265
# Epoch 28, average minibatch 200 loss: 0.286
# Epoch 28, average minibatch 250 loss: 0.271
# Epoch 28, average minibatch 300 loss: 0.305
# Epoch 28, average minibatch 350 loss: 0.376
# Finished 28 epochs of training
# Accuracy: 57.106
# Epoch 29, average minibatch 50 loss: 0.210
# Epoch 29, average minibatch 100 loss: 0.191
# Epoch 29, average minibatch 150 loss: 0.210
# Epoch 29, average minibatch 200 loss: 0.234
# Epoch 29, average minibatch 250 loss: 0.321
# Epoch 29, average minibatch 300 loss: 0.251
# Epoch 29, average minibatch 350 loss: 0.258
# Finished 29 epochs of training
# Accuracy: 57.362
# Epoch 30, average minibatch 50 loss: 0.185
# Epoch 30, average minibatch 100 loss: 0.176
# Epoch 30, average minibatch 150 loss: 0.186
# Epoch 30, average minibatch 200 loss: 0.226
# Epoch 30, average minibatch 250 loss: 0.215
# Epoch 30, average minibatch 300 loss: 0.318
# Epoch 30, average minibatch 350 loss: 0.259
# Finished 30 epochs of training
# Accuracy: 58.787
# Epoch 31, average minibatch 50 loss: 0.148
# Epoch 31, average minibatch 100 loss: 0.146
# Epoch 31, average minibatch 150 loss: 0.226
# Epoch 31, average minibatch 200 loss: 0.250
# Epoch 31, average minibatch 250 loss: 0.241
# Epoch 31, average minibatch 300 loss: 0.250
# Epoch 31, average minibatch 350 loss: 0.276
# Finished 31 epochs of training
# Accuracy: 56.468
# Epoch 32, average minibatch 50 loss: 0.251
# Epoch 32, average minibatch 100 loss: 0.200
# Epoch 32, average minibatch 150 loss: 0.236
# Epoch 32, average minibatch 200 loss: 0.199
# Epoch 32, average minibatch 250 loss: 0.187
# Epoch 32, average minibatch 300 loss: 0.212
# Epoch 32, average minibatch 350 loss: 0.269
# Finished 32 epochs of training
# Accuracy: 58.298
# Epoch 33, average minibatch 50 loss: 0.166
# Epoch 33, average minibatch 100 loss: 0.171
# Epoch 33, average minibatch 150 loss: 0.156
# Epoch 33, average minibatch 200 loss: 0.210
# Epoch 33, average minibatch 250 loss: 0.229
# Epoch 33, average minibatch 300 loss: 0.245
# Epoch 33, average minibatch 350 loss: 0.243
# Finished 33 epochs of training
# Accuracy: 57.000
# Epoch 34, average minibatch 50 loss: 0.196
# Epoch 34, average minibatch 100 loss: 0.185
# Epoch 34, average minibatch 150 loss: 0.203
# Epoch 34, average minibatch 200 loss: 0.194
# Epoch 34, average minibatch 250 loss: 0.211
# Epoch 34, average minibatch 300 loss: 0.179
# Epoch 34, average minibatch 350 loss: 0.201
# Finished 34 epochs of training
# Accuracy: 57.617
# Epoch 35, average minibatch 50 loss: 0.148
# Epoch 35, average minibatch 100 loss: 0.190
# Epoch 35, average minibatch 150 loss: 0.156
# Epoch 35, average minibatch 200 loss: 0.196
# Epoch 35, average minibatch 250 loss: 0.215
# Epoch 35, average minibatch 300 loss: 0.241
# Epoch 35, average minibatch 350 loss: 0.208
# Finished 35 epochs of training
# Accuracy: 58.000
# Epoch 36, average minibatch 50 loss: 0.159
# Epoch 36, average minibatch 100 loss: 0.148
# Epoch 36, average minibatch 150 loss: 0.166
# Epoch 36, average minibatch 200 loss: 0.153
# Epoch 36, average minibatch 250 loss: 0.189
# Epoch 36, average minibatch 300 loss: 0.220
# Epoch 36, average minibatch 350 loss: 0.222
# Finished 36 epochs of training
# Accuracy: 56.213
# Epoch 37, average minibatch 50 loss: 0.142
# Epoch 37, average minibatch 100 loss: 0.126
# Epoch 37, average minibatch 150 loss: 0.165
# Epoch 37, average minibatch 200 loss: 0.182
# Epoch 37, average minibatch 250 loss: 0.169
# Epoch 37, average minibatch 300 loss: 0.172
# Epoch 37, average minibatch 350 loss: 0.153
# Finished 37 epochs of training
# Accuracy: 59.468
# Epoch 38, average minibatch 50 loss: 0.167
# Epoch 38, average minibatch 100 loss: 0.141
# Epoch 38, average minibatch 150 loss: 0.170
# Epoch 38, average minibatch 200 loss: 0.166
# Epoch 38, average minibatch 250 loss: 0.178
# Epoch 38, average minibatch 300 loss: 0.209
# Epoch 38, average minibatch 350 loss: 0.229
# Finished 38 epochs of training
# Accuracy: 58.149
# Epoch 39, average minibatch 50 loss: 0.189
# Epoch 39, average minibatch 100 loss: 0.144
# Epoch 39, average minibatch 150 loss: 0.139
# Epoch 39, average minibatch 200 loss: 0.172
# Epoch 39, average minibatch 250 loss: 0.188
# Epoch 39, average minibatch 300 loss: 0.181
# Epoch 39, average minibatch 350 loss: 0.204
# Finished 39 epochs of training
# Accuracy: 58.872
# Epoch 40, average minibatch 50 loss: 0.163
# Epoch 40, average minibatch 100 loss: 0.163
# Epoch 40, average minibatch 150 loss: 0.146
# Epoch 40, average minibatch 200 loss: 0.147
# Epoch 40, average minibatch 250 loss: 0.192
# Epoch 40, average minibatch 300 loss: 0.161
# Epoch 40, average minibatch 350 loss: 0.150
# Finished 40 epochs of training
# Accuracy: 56.468
# Epoch 41, average minibatch 50 loss: 0.157
# Epoch 41, average minibatch 100 loss: 0.138
# Epoch 41, average minibatch 150 loss: 0.135
# Epoch 41, average minibatch 200 loss: 0.139
# Epoch 41, average minibatch 250 loss: 0.197
# Epoch 41, average minibatch 300 loss: 0.198
# Epoch 41, average minibatch 350 loss: 0.186
# Finished 41 epochs of training
# Accuracy: 60.532
# Epoch 42, average minibatch 50 loss: 0.118
# Epoch 42, average minibatch 100 loss: 0.123
# Epoch 42, average minibatch 150 loss: 0.126
# Epoch 42, average minibatch 200 loss: 0.136
# Epoch 42, average minibatch 250 loss: 0.157
# Epoch 42, average minibatch 300 loss: 0.214
# Epoch 42, average minibatch 350 loss: 0.210
# Finished 42 epochs of training
# Accuracy: 56.723
# Epoch 43, average minibatch 50 loss: 0.161
# Epoch 43, average minibatch 100 loss: 0.137
# Epoch 43, average minibatch 150 loss: 0.150
# Epoch 43, average minibatch 200 loss: 0.116
# Epoch 43, average minibatch 250 loss: 0.121
# Epoch 43, average minibatch 300 loss: 0.136
# Epoch 43, average minibatch 350 loss: 0.159
# Finished 43 epochs of training
# Accuracy: 58.660
# Epoch 44, average minibatch 50 loss: 0.157
# Epoch 44, average minibatch 100 loss: 0.146
# Epoch 44, average minibatch 150 loss: 0.167
# Epoch 44, average minibatch 200 loss: 0.173
# Epoch 44, average minibatch 250 loss: 0.190
# Epoch 44, average minibatch 300 loss: 0.175
# Epoch 44, average minibatch 350 loss: 0.165
# Finished 44 epochs of training
# Accuracy: 57.426
# Epoch 45, average minibatch 50 loss: 0.133
# Epoch 45, average minibatch 100 loss: 0.106
# Epoch 45, average minibatch 150 loss: 0.111
# Epoch 45, average minibatch 200 loss: 0.123
# Epoch 45, average minibatch 250 loss: 0.136
# Epoch 45, average minibatch 300 loss: 0.167
# Epoch 45, average minibatch 350 loss: 0.180
# Finished 45 epochs of training
# Accuracy: 59.404
# Epoch 46, average minibatch 50 loss: 0.112
# Epoch 46, average minibatch 100 loss: 0.111
# Epoch 46, average minibatch 150 loss: 0.105
# Epoch 46, average minibatch 200 loss: 0.112
# Epoch 46, average minibatch 250 loss: 0.139
# Epoch 46, average minibatch 300 loss: 0.176
# Epoch 46, average minibatch 350 loss: 0.148
# Finished 46 epochs of training
# Accuracy: 58.064
# Epoch 47, average minibatch 50 loss: 0.161
# Epoch 47, average minibatch 100 loss: 0.170
# Epoch 47, average minibatch 150 loss: 0.140
# Epoch 47, average minibatch 200 loss: 0.161
# Epoch 47, average minibatch 250 loss: 0.170
# Epoch 47, average minibatch 300 loss: 0.138
# Epoch 47, average minibatch 350 loss: 0.161
# Finished 47 epochs of training
# Accuracy: 59.255
# Epoch 48, average minibatch 50 loss: 0.129
# Epoch 48, average minibatch 100 loss: 0.109
# Epoch 48, average minibatch 150 loss: 0.148
# Epoch 48, average minibatch 200 loss: 0.113
# Epoch 48, average minibatch 250 loss: 0.159
# Epoch 48, average minibatch 300 loss: 0.133
# Epoch 48, average minibatch 350 loss: 0.134
# Finished 48 epochs of training
# Accuracy: 59.915
# Epoch 49, average minibatch 50 loss: 0.132
# Epoch 49, average minibatch 100 loss: 0.093
# Epoch 49, average minibatch 150 loss: 0.113
# Epoch 49, average minibatch 200 loss: 0.130
# Epoch 49, average minibatch 250 loss: 0.113
# Epoch 49, average minibatch 300 loss: 0.120
# Epoch 49, average minibatch 350 loss: 0.143
# Finished 49 epochs of training
# Accuracy: 58.702
# Epoch 50, average minibatch 50 loss: 0.157
# Epoch 50, average minibatch 100 loss: 0.173
# Epoch 50, average minibatch 150 loss: 0.136
# Epoch 50, average minibatch 200 loss: 0.126
# Epoch 50, average minibatch 250 loss: 0.097
# Epoch 50, average minibatch 300 loss: 0.119
# Epoch 50, average minibatch 350 loss: 0.167
# Finished 50 epochs of training
# Accuracy: 57.319
